# %%
import os
import django
import pandas as pd
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'fxfutbol.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
import http.client
import pandas as pd
import json
from datetime import datetime, timedelta

class ResultAPI:
    def __init__(self, start_date="2023-01-01", extra_days=0):
        self.start_date = start_date
        self.extra_days = extra_days
        self.full_df = pd.DataFrame()

    def gunluk_fikstur(self, tarih):
        try:
            conn = http.client.HTTPSConnection('www.sofascore.com')
            conn.request(
                'GET',
                f'/api/v1/sport/football/scheduled-events/{tarih}'
            )
            response = conn.getresponse()
            data = response.read()
            data = json.loads(data)["events"]

            model_data = [{
                'tarih': tarih,
                'processed': False,
                'data': data,
                'isData':True
            }]
            
            df = pd.DataFrame(model_data)
        except Exception as e:
            model_data = [{
                'tarih': tarih,
                'processed': False,
                'data': [],
                'isData':False
            }]
            df = pd.DataFrame(model_data)
        
        return df

    def generate_dates_and_future(self):
        start_date = datetime.strptime(self.start_date, "%Y-%m-%d")
        current_date = datetime.now()
        date_list = []

        while start_date <= current_date:
            date_list.append(start_date.strftime("%Y-%m-%d"))
            start_date += timedelta(days=1)

        for i in range(1, self.extra_days + 1):
            future_date = current_date + timedelta(days=i)
            date_list.append(future_date.strftime("%Y-%m-%d"))

        return date_list

    def guncelleme(self):
        print("Çekim İşlemleri Başladı")
        tarihler = self.generate_dates_and_future()
        full_df = pd.DataFrame()

        for tarih in tarihler:
            print(f"{tarih} tarih verisi çekiliyor")
            data = self.gunluk_fikstur(tarih)
            full_df = pd.concat([full_df, data], ignore_index=True)

        print("Veriler Güncellendi")
        self.full_df = full_df
        return self.full_df

    def result_process(self, df):
        if df.empty:
            return pd.DataFrame()

        df_exploded = df.explode('data')
        expanded_data = pd.json_normalize(df_exploded['data'])
        
        if expanded_data.empty:
            return expanded_data
        
        expanded_data['tarih'] = list(df_exploded['tarih'])
        expanded_data['processed'] = list(df_exploded['processed'])

        data = expanded_data.drop_duplicates(subset='id', keep='last')
        data = data[data["status.type"] == "finished"]
        data["startTimestamp"] = pd.to_datetime(data['startTimestamp'], unit='s') + pd.Timedelta(hours=3)

        return data

    def fetch_and_process(self):
        """
        Tüm işlemleri çalıştırarak, ham ve işlenmiş veriyi ayrı döner.
        
        Returns:
            Tuple[pd.DataFrame, pd.DataFrame]: (Ham Veri, İşlenmiş Veri)
        """
        # Güncelleme ve ham verileri çek
        raw_data = self.guncelleme()
        
        # Veriyi işle
        processed_data = self.result_process(raw_data)
        
        return raw_data, processed_data


api = ResultAPI(start_date="2024-10-08", extra_days=0)
raw_data = api.guncelleme()
raw_data
# Out:
# Çekim İşlemleri Başladı
# 2024-10-08 tarih verisi çekiliyor
# 2024-10-09 tarih verisi çekiliyor
# Veriler Güncellendi
#         tarih  processed                                               data  \
# 0  2024-10-08      False  [{'tournament': {'name': 'Liga Profesional', '...
# 1  2024-10-09      False  [{'tournament': {'name': 'Africa Cup of Nation...
#
#    isData
# 0    True
# 1    True

# %%
df = raw_data
from analysis.models import FixtureData
import pandas as pd

tarih_list = df['tarih'].tolist()
FixtureData.objects.filter(tarih__in=tarih_list).delete()

# `DataFrame`'deki her bir satırı `FixtureData` modeline dönüştürme ve `fixture_list` oluşturma
fixture_list = [
    FixtureData(
        tarih=row['tarih'],
        processed=row['processed'],
        data=row['data'],
        isData=row['isData']
    )
    for index, row in df.iterrows()
]

# `bulk_create` ile veritabanına toplu olarak ekleme
FixtureData.objects.bulk_create(fixture_list)

print("Mevcut veriler silindi ve yeni veriler eklendi.")
print("Toplu veri ekleme işlemi tamamlandı.")
# Out:
# Mevcut veriler silindi ve yeni veriler eklendi.
# Toplu veri ekleme işlemi tamamlandı.

# %%
from analysis.models import FixtureData
fixture_data = FixtureData.objects.all().values()
df_lite = pd.DataFrame(list(fixture_data))
df_lite
# Out:
#    id       tarih  processed  \
# 0  51  2024-10-06      False
# 1  52  2024-10-07      False
# 2  55  2024-10-08      False
# 3  56  2024-10-09      False
#
#                                                 data  isData  \
# 0  [{'tournament': {'name': 'Premier League', 'sl...    True
# 1  [{'tournament': {'name': 'Premier League', 'sl...    True
# 2  [{'tournament': {'name': 'Liga Profesional', '...    True
# 3  [{'tournament': {'name': 'Africa Cup of Nation...    True
#
#                        update_date
# 0 2024-10-09 20:03:53.878390+00:00
# 1 2024-10-09 20:03:53.882769+00:00
# 2 2024-10-09 20:04:08.027741+00:00
# 3 2024-10-09 20:04:08.029168+00:00

# %%
df_exploded = df_lite.explode('data')
df_exploded
# Out:
#     id       tarih  processed  \
# 0   51  2024-10-06      False
# 0   51  2024-10-06      False
# 0   51  2024-10-06      False
# 0   51  2024-10-06      False
# 0   51  2024-10-06      False
# ..  ..         ...        ...
# 3   56  2024-10-09      False
# 3   56  2024-10-09      False
# 3   56  2024-10-09      False
# 3   56  2024-10-09      False
# 3   56  2024-10-09      False
#
#                                                  data  isData  \
# 0   {'tournament': {'name': 'Premier League', 'slu...    True
# 0   {'tournament': {'name': 'Premier League', 'slu...    True
# 0   {'tournament': {'name': 'Premier League', 'slu...    True
# 0   {'tournament': {'name': 'Premier League', 'slu...    True
# 0   {'tournament': {'name': 'Premier League', 'slu...    True
# ..                                                ...     ...
# 3   {'tournament': {'name': 'U19 Friendly Games', ...    True
# 3   {'tournament': {'name': 'U19 Friendly Games', ...    True
# 3   {'tournament': {'name': 'U19 Friendly Games', ...    True
# 3   {'tournament': {'name': 'U19 Friendly Games', ...    True
# 3   {'tournament': {'name': 'U19 Friendly Games', ...    True
#
#                         update_date
# 0  2024-10-09 20:03:53.878390+00:00
# 0  2024-10-09 20:03:53.878390+00:00
# 0  2024-10-09 20:03:53.878390+00:00
# 0  2024-10-09 20:03:53.878390+00:00
# 0  2024-10-09 20:03:53.878390+00:00
# ..                              ...
# 3  2024-10-09 20:04:08.029168+00:00
# 3  2024-10-09 20:04:08.029168+00:00
# 3  2024-10-09 20:04:08.029168+00:00
# 3  2024-10-09 20:04:08.029168+00:00
# 3  2024-10-09 20:04:08.029168+00:00
#
# [1281 rows x 6 columns]

# %%
pd.DataFrame(dfx["data"]).to_excel("Explode_data.xlsx")

# %%
pd.DataFrame(df1).columns
# Out:
# Index(['tournament', 'season', 'roundInfo', 'customId', 'status', 'winnerCode',
#        'homeTeam', 'awayTeam', 'homeScore', 'awayScore', 'time', 'changes',
#        'hasGlobalHighlights', 'hasEventPlayerStatistics',
#        'hasEventPlayerHeatMap', 'detailId', 'crowdsourcingDataDisplayEnabled',
#        'id', 'startTimestamp', 'slug', 'finalResultOnly', 'feedLocked',
#        'isEditor', 'awayRedCards', 'homeRedCards', 'aggregatedWinnerCode',
#        'previousLegEventId', 'isAwarded', 'coverage'],
#       dtype='object')

# %%
df1[55]["tournament"]
# Out:
# {'name': 'Eredivisie',
#  'slug': 'eredivisie',
#  'category': {'name': 'Netherlands',
#   'slug': 'netherlands',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'id': 35,
#   'country': {'alpha2': 'NL',
#    'alpha3': 'NLD',
#    'name': 'Netherlands',
#    'slug': 'netherlands'},
#   'flag': 'netherlands',
#   'alpha2': 'NL'},
#  'uniqueTournament': {'name': 'Eredivisie',
#   'slug': 'eredivisie',
#   'category': {'name': 'Netherlands',
#    'slug': 'netherlands',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 35,
#    'country': {'alpha2': 'NL',
#     'alpha3': 'NLD',
#     'name': 'Netherlands',
#     'slug': 'netherlands'},
#    'flag': 'netherlands',
#    'alpha2': 'NL'},
#   'userCount': 234222,
#   'id': 37,
#   'hasEventPlayerStatistics': True,
#   'displayInverseHomeAwayTeams': False},
#  'priority': 453,
#  'id': 39}

# %%
df1[0]
# Out:
# [{'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'Vsab',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Brentford',
#    'slug': 'brentford',
#    'shortName': 'Brentford',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 365182,
#    'nameCode': 'BRE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 50,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'برينتفورد',
#      'ru': 'Брентфорд'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Southampton',
#    'slug': 'southampton',
#    'shortName': 'Southampton',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 214774,
#    'nameCode': 'SOU',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 45,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ساوثهامتون',
#      'ru': 'Саутгемптон'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 3,
#    'display': 3,
#    'period1': 1,
#    'period2': 2,
#    'normaltime': 3},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'time': {'injuryTime1': 3,
#    'injuryTime2': 6,
#    'currentPeriodStartTimestamp': 1725116654},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'awayScore.period2',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1725119749},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436908,
#   'startTimestamp': 1725112800,
#   'slug': 'brentford-southampton',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'Yskb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Everton',
#    'slug': 'everton',
#    'shortName': 'Everton',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 480293,
#    'nameCode': 'EVE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 48,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'إيفرتون', 'ru': 'Эвертон'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Bournemouth',
#    'slug': 'bournemouth',
#    'shortName': 'Bournemouth',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 278784,
#    'nameCode': 'BOU',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 60,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'بورنموث', 'ru': 'Борнмут'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 2,
#    'display': 2,
#    'period1': 0,
#    'period2': 2,
#    'normaltime': 2},
#   'awayScore': {'current': 3,
#    'display': 3,
#    'period1': 0,
#    'period2': 3,
#    'normaltime': 3},
#   'time': {'injuryTime1': 1,
#    'injuryTime2': 6,
#    'currentPeriodStartTimestamp': 1725116594},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'awayScore.period2',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1725119773},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436912,
#   'startTimestamp': 1725112800,
#   'slug': 'bournemouth-everton',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'HsT',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 3,
#   'homeTeam': {'name': 'Ipswich Town',
#    'slug': 'ipswich-town',
#    'shortName': 'Ipswich',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 125128,
#    'nameCode': 'IPS',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 32,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ايبسويتش تاون',
#      'ru': 'Ипсвич Таун'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Fulham',
#    'slug': 'fulham',
#    'shortName': 'Fulham',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 406620,
#    'nameCode': 'FUL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 43,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فولهام', 'ru': 'Фулхэм'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 5,
#    'currentPeriodStartTimestamp': 1725116613},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725119625},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436915,
#   'startTimestamp': 1725112800,
#   'slug': 'fulham-ipswich-town',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'GP',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Leicester City',
#    'slug': 'leicester-city',
#    'shortName': 'Leicester',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 555044,
#    'nameCode': 'LEI',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 31,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ليستر سيتي',
#      'ru': 'Лестер Сити'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Aston Villa',
#    'slug': 'aston-villa',
#    'shortName': 'Aston Villa',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 820089,
#    'nameCode': 'AVL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 40,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'أستون فيلا',
#      'ru': 'Астон Вилла'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'awayScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 7,
#    'currentPeriodStartTimestamp': 1725116639},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725119833},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436918,
#   'startTimestamp': 1725112800,
#   'slug': 'aston-villa-leicester-city',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'dso',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 3,
#   'homeTeam': {'name': 'Nottingham Forest',
#    'slug': 'nottingham-forest',
#    'shortName': 'Forest',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 307050,
#    'nameCode': 'NFO',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 14,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نوتنجهام فوريست',
#      'ru': 'Ноттингем Форест'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Wolverhampton',
#    'slug': 'wolverhampton',
#    'shortName': 'Wolves',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 421133,
#    'nameCode': 'WOL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'وولفرهامبتون واندررز',
#      'ru': 'Вулверхэмптон Уондерерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 10,
#    'currentPeriodStartTimestamp': 1725116675},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725119991},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436926,
#   'startTimestamp': 1725112800,
#   'slug': 'nottingham-forest-wolverhampton',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'rM',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'West Ham United',
#    'slug': 'west-ham-united',
#    'shortName': 'West Ham',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 707106,
#    'nameCode': 'WHU',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 37,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'وست هام يونايتد',
#      'ru': 'Вест Хэм Юнайтед'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Manchester City',
#    'slug': 'manchester-city',
#    'shortName': 'Man City',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 3107738,
#    'nameCode': 'MCI',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 17,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانشستر سيتي',
#      'ru': 'Манчестер Сити'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 3,
#    'display': 3,
#    'period1': 2,
#    'period2': 1,
#    'normaltime': 3},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 5,
#    'currentPeriodStartTimestamp': 1725125622},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725128655},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436927,
#   'startTimestamp': 1725121800,
#   'slug': 'west-ham-united-manchester-city',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'hN',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 3,
#   'homeTeam': {'name': 'Chelsea',
#    'slug': 'chelsea',
#    'shortName': 'Chelsea',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2197892,
#    'nameCode': 'CHE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 38,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'تشيلسي', 'ru': 'Челси'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Crystal Palace',
#    'slug': 'crystal-palace',
#    'shortName': 'Crystal Palace',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 402540,
#    'nameCode': 'CRY',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 7,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستال بالاس',
#      'ru': 'Кристал Пэлас'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'time': {'injuryTime1': 3,
#    'injuryTime2': 8,
#    'currentPeriodStartTimestamp': 1725197658},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725200875},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436910,
#   'startTimestamp': 1725193800,
#   'slug': 'chelsea-crystal-palace',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'IO',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Newcastle United',
#    'slug': 'newcastle-united',
#    'shortName': 'Newcastle',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 935430,
#    'nameCode': 'NEW',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 39,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيوكاسل يونايتد',
#      'ru': 'Ньюкасл Юнайтед'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Tottenham Hotspur',
#    'slug': 'tottenham-hotspur',
#    'shortName': 'Tottenham ',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 1374662,
#    'nameCode': 'TOT',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 33,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'توتنهام هوتسبير',
#      'ru': 'Тоттенхэм Хотспур'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'time': {'injuryTime1': 5,
#    'injuryTime2': 5,
#    'currentPeriodStartTimestamp': 1725197828},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725200901},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436923,
#   'startTimestamp': 1725193800,
#   'slug': 'newcastle-united-tottenham-hotspur',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN'},
#    'uniqueTournament': {'name': 'Premier League',
#     'slug': 'premier-league',
#     'category': {'name': 'England',
#      'slug': 'england',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'flag': 'england',
#      'alpha2': 'EN'},
#     'userCount': 1909020,
#     'id': 17,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 611,
#    'id': 1},
#   'season': {'name': 'Premier League 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61627},
#   'roundInfo': {'round': 3},
#   'customId': 'KU',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Manchester United',
#    'slug': 'manchester-united',
#    'shortName': 'Man Utd',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2778016,
#    'nameCode': 'MUN',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 35,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانتشستر يونايتد',
#      'ru': 'Манчестер Юнайтед'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Liverpool',
#    'slug': 'liverpool',
#    'shortName': 'Liverpool',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2647983,
#    'nameCode': 'LIV',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 44,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ليفربول',
#      'ru': 'Ливерпуль'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'awayScore': {'current': 3,
#    'display': 3,
#    'period1': 2,
#    'period2': 1,
#    'normaltime': 3},
#   'time': {'injuryTime1': 5,
#    'injuryTime2': 5,
#    'currentPeriodStartTimestamp': 1725206743},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725209757},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12436920,
#   'startTimestamp': 1725202800,
#   'slug': 'liverpool-manchester-united',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'rgbsGgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Barcelona',
#    'slug': 'barcelona',
#    'shortName': 'Barcelona',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 3651634,
#    'nameCode': 'FCB',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2817,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'برشلونة',
#      'ru': 'Барселона'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Real Valladolid',
#    'slug': 'real-valladolid',
#    'shortName': 'Real Valladolid',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 111883,
#    'nameCode': 'VLL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2831,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ريال بلد الوليد',
#      'ru': 'Реал Вальядолид'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 7,
#    'display': 7,
#    'period1': 3,
#    'period2': 4,
#    'normaltime': 7},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 4,
#    'injuryTime2': 2,
#    'currentPeriodStartTimestamp': 1725120376},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725123210},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437687,
#   'startTimestamp': 1725116400,
#   'slug': 'real-valladolid-barcelona',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'AgbsLgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Athletic Club',
#    'slug': 'athletic-club',
#    'shortName': 'Athletic Club',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 480032,
#    'nameCode': 'ATH',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2825,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اتلتيك دي بلباو',
#      'ru': 'Атлетик Бильбао'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Atlético Madrid',
#    'slug': 'atletico-madrid',
#    'shortName': 'Atl. Madrid',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 1466270,
#    'nameCode': 'ATM',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2836,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اتلتيكو مدريد',
#      'ru': 'Атлетико Мадрид'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'time': {'injuryTime1': 0,
#    'injuryTime2': 6,
#    'currentPeriodStartTimestamp': 1725127362},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725130492},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437684,
#   'startTimestamp': 1725123600,
#   'slug': 'atletico-madrid-athletic-club',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'ogbstgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Espanyol',
#    'slug': 'espanyol',
#    'shortName': 'Espanyol',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 139739,
#    'nameCode': 'ESP',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2814,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اسبانيول برشلونة',
#      'ru': 'Эспаньол'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Rayo Vallecano',
#    'slug': 'rayo-vallecano',
#    'shortName': 'Rayo Vallecano',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 204449,
#    'nameCode': 'RVM',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2818,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'رايو فاليكانو',
#      'ru': 'Райо Вальекано'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'time': {'injuryTime1': 6,
#    'injuryTime2': 9,
#    'currentPeriodStartTimestamp': 1725128612},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725131952},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437699,
#   'startTimestamp': 1725124500,
#   'slug': 'rayo-vallecano-espanyol',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'BgbsVgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Leganés',
#    'slug': 'leganes',
#    'shortName': 'Leganés',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 53470,
#    'nameCode': 'LEG',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2845,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ليغانيس', 'ru': 'Леганес'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Mallorca',
#    'slug': 'mallorca',
#    'shortName': 'Mallorca',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 210666,
#    'nameCode': 'MLL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2826,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ريال مايوركا',
#      'ru': 'Мальорка'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 4,
#    'currentPeriodStartTimestamp': 1725136412},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725139363},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437697,
#   'startTimestamp': 1725132600,
#   'slug': 'leganes-mallorca',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'ugbsDgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 3,
#   'homeTeam': {'name': 'Valencia',
#    'slug': 'valencia',
#    'shortName': 'Valencia',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 371595,
#    'nameCode': 'VCF',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2828,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فالنسيا',
#      'ru': 'Валенсия'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Villarreal',
#    'slug': 'villarreal',
#    'shortName': 'Villarreal',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 490493,
#    'nameCode': 'VIL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2819,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فياريال',
#      'ru': 'Вильярреал'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'time': {'injuryTime1': 3,
#    'injuryTime2': 4,
#    'currentPeriodStartTimestamp': 1725136711},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725139703},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437692,
#   'awayRedCards': 1,
#   'startTimestamp': 1725132600,
#   'slug': 'valencia-villarreal',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'KhbsCGc',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Deportivo Alavés',
#    'slug': 'deportivo-alaves',
#    'shortName': 'Alavés',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 159917,
#    'nameCode': 'ALA',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2885,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديبورتيفو ألافيس',
#      'ru': 'Алавес'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Las Palmas',
#    'slug': 'las-palmas',
#    'shortName': 'Las Palmas',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 148092,
#    'nameCode': 'LPA',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 6577,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'يونيون ديبورتيفا لاس بالماس',
#      'ru': 'Лас-Пальмас'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 4,
#    'injuryTime2': 5,
#    'currentPeriodStartTimestamp': 1725206690},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1725209702},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'detailId': 1,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12437694,
#   'startTimestamp': 1725202800,
#   'slug': 'las-palmas-deportivo-alaves',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'country': {'alpha2': 'ES',
#      'alpha3': 'ESP',
#      'name': 'Spain',
#      'slug': 'spain'},
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1286130,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 610,
#    'id': 36},
#   'season': {'name': 'LaLiga 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 61643},
#   'roundInfo': {'round': 4},
#   'customId': 'vgbswgb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Osasuna',
#    'slug': 'osasuna',
#    'shortName': 'Osasuna',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 223009,
#    'nameCode': 'OSA',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2820,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اوساسونا',
#      'ru': 'Осасуна'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Celta Vigo',
#    'slug': 'celta-vigo',
#    'shortName': 'Celta',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 228584,
#    'nameCode': 'RCC',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 2821,
# ...
#    'display': 3,
#    'period1': 1,
#    'period2': 2,
#    'normaltime': 3},
#   'awayScore': {'current': 3,
#    'display': 3,
#    'period1': 2,
#    'period2': 1,
#    'normaltime': 3},
#   'time': {'currentPeriodStartTimestamp': 1725138180},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1725141367},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402440,
#   'startTimestamp': 1725134400,
#   'slug': 'canada-u20-france-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'U20 FIFA World Cup, Women, Group B',
#    'slug': 'u20-womens-world-championship-group-b',
#    'category': {'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1468,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': "U-20 Women's World Championship",
#     'slug': 'u20-world-championship-women',
#     'category': {'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1468,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 10398,
#     'id': 804,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 13106},
#   'season': {'name': 'U20 Womens World Cup 2024',
#    'year': '2024',
#    'editor': False,
#    'seasonCoverageInfo': {'editorCoverageLevel': 1},
#    'id': 61242},
#   'roundInfo': {'round': 1},
#   'customId': 'qorsQpje',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Brazil U20',
#    'slug': 'brazil-u20',
#    'shortName': 'Brazil U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 7280,
#    'nameCode': 'BRA',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 43216,
#    'country': {'alpha2': 'BR',
#     'alpha3': 'BRA',
#     'name': 'Brazil',
#     'slug': 'brazil'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'البرازيل تحت 20',
#      'ru': 'Бразилия U20'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Fiji U20',
#    'slug': 'fiji-u20-u20',
#    'shortName': 'Fiji U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 281,
#    'nameCode': 'FIJ',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 523291,
#    'country': {'alpha2': 'FJ',
#     'alpha3': 'FJI',
#     'name': 'Fiji',
#     'slug': 'fiji'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 9,
#    'display': 9,
#    'period1': 5,
#    'period2': 4,
#    'normaltime': 9},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 2,
#    'injuryTime2': 4,
#    'currentPeriodStartTimestamp': 1725151901},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'awayScore.normaltime',
#     'time.currentPeriodStart'],
#    'changeTimestamp': 1725151905},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402437,
#   'startTimestamp': 1725145200,
#   'slug': 'fiji-u20-brazil-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'U20 FIFA World Cup, Women, Group C',
#    'slug': 'u20-womens-world-championship-group-c',
#    'category': {'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1468,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': "U-20 Women's World Championship",
#     'slug': 'u20-world-championship-women',
#     'category': {'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1468,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 10398,
#     'id': 804,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 13107},
#   'season': {'name': 'U20 Womens World Cup 2024',
#    'year': '2024',
#    'editor': False,
#    'seasonCoverageInfo': {'editorCoverageLevel': 1},
#    'id': 61242},
#   'roundInfo': {'round': 1},
#   'customId': 'AorsUNUb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Spain U20',
#    'slug': 'spain-u20',
#    'shortName': 'Spain U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2733,
#    'nameCode': 'ESP',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 236944,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'Spain تحت 20'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'USA U20',
#    'slug': 'usa-u20',
#    'shortName': 'USA U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2100,
#    'nameCode': 'USA',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 43225,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'الولايات المتحدة تحت 20',
#      'ru': 'США U20'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 1,
#    'period2': 0,
#    'normaltime': 1},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 4,
#    'injuryTime2': 8,
#    'currentPeriodStartTimestamp': 1725227878},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'time.currentPeriodStart'],
#    'changeTimestamp': 1725227881},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402433,
#   'startTimestamp': 1725220800,
#   'slug': 'spain-u20-usa-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'U20 FIFA World Cup, Women, Group C',
#    'slug': 'u20-womens-world-championship-group-c',
#    'category': {'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1468,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': "U-20 Women's World Championship",
#     'slug': 'u20-world-championship-women',
#     'category': {'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1468,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 10398,
#     'id': 804,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 13107},
#   'season': {'name': 'U20 Womens World Cup 2024',
#    'year': '2024',
#    'editor': False,
#    'seasonCoverageInfo': {'editorCoverageLevel': 1},
#    'id': 61242},
#   'roundInfo': {'round': 1},
#   'customId': 'IEuspUbe',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Paraguay U20',
#    'slug': 'paraguay-u20',
#    'shortName': 'Paraguay U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 1283,
#    'nameCode': 'PAR',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 48983,
#    'country': {'alpha2': 'PY',
#     'alpha3': 'PRY',
#     'name': 'Paraguay',
#     'slug': 'paraguay'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'الباراغواي تحت 20',
#      'ru': 'Парагвай U20'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Morocco U20',
#    'slug': 'morocco-u20',
#    'shortName': 'Morocco U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 1732,
#    'nameCode': 'MU2',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 504715,
#    'country': {'alpha2': 'MA',
#     'alpha3': 'MAR',
#     'name': 'Morocco',
#     'slug': 'morocco'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 1,
#    'injuryTime2': 6,
#    'currentPeriodStartTimestamp': 1725238478},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1725238485},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402430,
#   'startTimestamp': 1725231600,
#   'slug': 'morocco-u20-paraguay-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'U20 FIFA World Cup, Women, Group D',
#    'slug': 'u20-womens-world-championship-group-d',
#    'category': {'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1468,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': "U-20 Women's World Championship",
#     'slug': 'u20-world-championship-women',
#     'category': {'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1468,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 10398,
#     'id': 804,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 13108},
#   'season': {'name': 'U20 Womens World Cup 2024',
#    'year': '2024',
#    'editor': False,
#    'seasonCoverageInfo': {'editorCoverageLevel': 1},
#    'id': 61242},
#   'roundInfo': {'round': 1},
#   'customId': 'morsDEu',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Germany U20',
#    'slug': 'germany-u20',
#    'shortName': 'Germany U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 2363,
#    'nameCode': 'GER',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 43212,
#    'country': {'alpha2': 'DE',
#     'alpha3': 'DEU',
#     'name': 'Germany',
#     'slug': 'germany'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ألمانيا تحت 20',
#      'ru': 'Германия U20'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Venezuela U20',
#    'slug': 'venezuela-u20',
#    'shortName': 'Venezuela U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 1857,
#    'nameCode': 'VEN',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 48978,
#    'country': {'alpha2': 'VE',
#     'alpha3': 'VEN',
#     'name': 'Venezuela',
#     'slug': 'venezuela'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فنزويلا تحت 20',
#      'ru': 'Венесуэла U20'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 5,
#    'display': 5,
#    'period1': 4,
#    'period2': 1,
#    'normaltime': 5},
#   'awayScore': {'current': 2,
#    'display': 2,
#    'period1': 1,
#    'period2': 1,
#    'normaltime': 2},
#   'time': {'currentPeriodStartTimestamp': 1725225000},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1725227989},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402473,
#   'startTimestamp': 1725220800,
#   'slug': 'venezuela-u20-germany-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'tournament': {'name': 'U20 FIFA World Cup, Women, Group D',
#    'slug': 'u20-womens-world-championship-group-d',
#    'category': {'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1468,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': "U-20 Women's World Championship",
#     'slug': 'u20-world-championship-women',
#     'category': {'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 1468,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 10398,
#     'id': 804,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 13108},
#   'season': {'name': 'U20 Womens World Cup 2024',
#    'year': '2024',
#    'editor': False,
#    'seasonCoverageInfo': {'editorCoverageLevel': 1},
#    'id': 61242},
#   'roundInfo': {'round': 1},
#   'customId': 'rorsxor',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Nigeria U20',
#    'slug': 'nigeria-u20',
#    'shortName': 'Nigeria U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 3104,
#    'nameCode': 'NGR',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 43222,
#    'country': {'alpha2': 'NG',
#     'alpha3': 'NGA',
#     'name': 'Nigeria',
#     'slug': 'nigeria'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيجيريا تحت 20',
#      'ru': 'Нигерия U20'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'South Korea U20',
#    'slug': 'south-korea-u20',
#    'shortName': 'South Korea U20',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 934,
#    'nameCode': 'KOR',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 43217,
#    'country': {'alpha2': 'KR',
#     'alpha3': 'KOR',
#     'name': 'South Korea',
#     'slug': 'south-korea'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 1,
#    'display': 1,
#    'period1': 0,
#    'period2': 1,
#    'normaltime': 1},
#   'awayScore': {'current': 0,
#    'display': 0,
#    'period1': 0,
#    'period2': 0,
#    'normaltime': 0},
#   'time': {'injuryTime1': 1,
#    'injuryTime2': 7,
#    'currentPeriodStartTimestamp': 1725238687},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.period2',
#     'homeScore.normaltime',
#     'awayScore.period2',
#     'awayScore.normaltime',
#     'time.currentPeriodStart'],
#    'changeTimestamp': 1725238689},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'hasEventPlayerHeatMap': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12402474,
#   'startTimestamp': 1725231600,
#   'slug': 'nigeria-u20-south-korea-u20',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False}]
