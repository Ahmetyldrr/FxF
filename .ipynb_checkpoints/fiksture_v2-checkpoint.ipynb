# %%
import os
import django
import pandas as pd
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'fxfutbol.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
import ssl
import http.client
import json
import pandas as pd

class SofaScoreAPI:
    def __init__(self, match_id):
        self.match_id = match_id
        self.base_url = 'www.sofascore.com'

    def _make_request(self, endpoint):
        """
        Belirtilen endpoint'e HTTP isteği yapar ve yanıtı döner.
        """
        context = ssl._create_unverified_context()
        con = http.client.HTTPSConnection(self.base_url, context=context)
        try:
            con.request("GET", endpoint)
            response = con.getresponse()
            data = response.read()
            data = json.loads(data)
            return {"match_id":self.match_id,"response_code": response.status, "data": data}
        except Exception as e:
            con.request("GET", endpoint)
            response = con.getresponse()
            return {"match_id":self.match_id,"response_code": response.status , "data": None }

    def get_lineups(self):
        """
        Kadro bilgilerini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/lineups'
        return self._make_request(endpoint)

    def get_incidents(self):
        """
        Maç olaylarını döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/incidents'
        return self._make_request(endpoint)

    def get_graph(self):
        """
        Maç baskı grafiğini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/graph'
        return self._make_request(endpoint)

    def get_match_info(self):
        """
        Maç bilgilerini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}'
        return self._make_request(endpoint)

    def get_odds(self):
        """
        Maç oran bilgilerini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/odds/672/featured'
        return self._make_request(endpoint)

    def get_pregame_form(self):
        """
        Takım form bilgilerini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/pregame-form'
        return self._make_request(endpoint)

    def get_statistics(self):
        """
        Maç istatistiklerini döndürür.
        """
        endpoint = f'/api/v1/event/{self.match_id}/statistics'
        return self._make_request(endpoint)

    def fetch_all_data(self):
        """
        Tüm API endpoint'lerinden verileri toplar ve bir dict olarak döner.
        """
        return {
            "match_id": self.match_id,
            "lineups": self.get_lineups(),
            "incidents": self.get_incidents(),
            "graph": self.get_graph(),
            "match_info": self.get_match_info(),
            "odds": self.get_odds(),
            "pregame_form": self.get_pregame_form(),
            "statistics": self.get_statistics(),
        }
        
match_id = 12531328
sofa_api = SofaScoreAPI(match_id)
result_all = sofa_api.fetch_all_data()
result_all
# Out:
# {'match_id': 12531328,
#  'lineups': {'match_id': 12531328,
#   'response_code': 404,
#   'data': {'error': {'code': 404, 'message': 'Not Found'}}},
#  'incidents': {'match_id': 12531328,
#   'response_code': 200,
#   'data': {'incidents': [{'text': 'FT',
#      'homeScore': 3,
#      'awayScore': 2,
#      'isLive': False,
#      'time': 90,
#      'addedTime': 999,
#      'timeSeconds': 5400,
#      'reversedPeriodTime': 1,
#      'reversedPeriodTimeSeconds': 0,
#      'incidentType': 'period'},
#     {'from': 'regular',
#      'homeScore': 3,
#      'awayScore': 2,
#      'playerName': 'Cynthia Adamu',
#      'period': 'period2',
#      'id': 188019436,
#      'time': 80,
#      'isHome': True,
#      'incidentClass': 'regular',
#      'reversedPeriodTime': 11,
#      'incidentType': 'goal'},
#     {'from': 'regular',
#      'homeScore': 2,
#      'awayScore': 2,
#      'playerName': 'Lena Kovar ',
#      'period': 'period2',
#      'id': 188019237,
#      'time': 78,
#      'isHome': False,
#      'incidentClass': 'regular',
#      'reversedPeriodTime': 13,
#      'incidentType': 'goal'},
#     {'from': 'regular',
#      'homeScore': 2,
#      'awayScore': 1,
#      'playerName': 'Katharina Mayr',
#      'period': 'period2',
#      'id': 188018611,
#      'time': 66,
#      'isHome': True,
#      'incidentClass': 'regular',
#      'reversedPeriodTime': 25,
#      'incidentType': 'goal'},
#     {'from': 'regular',
#      'homeScore': 1,
#      'awayScore': 1,
#      'playerName': 'Hannah Frankhauser',
#      'period': 'period2',
#      'id': 188018158,
#      'time': 60,
#      'isHome': False,
#      'incidentClass': 'regular',
#      'reversedPeriodTime': 31,
#      'incidentType': 'goal'},
#     {'text': 'HT',
#      'homeScore': 1,
#      'awayScore': 0,
#      'isLive': False,
#      'time': 45,
#      'addedTime': 999,
#      'timeSeconds': 2700,
#      'reversedPeriodTime': 1,
#      'reversedPeriodTimeSeconds': 0,
#      'incidentType': 'period'},
#     {'from': 'regular',
#      'homeScore': 1,
#      'awayScore': 0,
#      'playerName': 'Andrea Svibkova ',
#      'period': 'period1',
#      'id': 188014259,
#      'time': 6,
#      'isHome': True,
#      'incidentClass': 'regular',
#      'reversedPeriodTime': 40,
#      'incidentType': 'goal'}],
#    'home': {'goalkeeperColor': {'primary': '000000',
#      'number': '222226',
#      'outline': '808080',
#      'fancyNumber': '222226'},
#     'playerColor': {'primary': '000000',
#      'number': '222226',
#      'outline': '808080',
#      'fancyNumber': '222226'}},
#    'away': {'goalkeeperColor': {'primary': '000000',
#      'number': '222226',
#      'outline': 'ed0202',
#      'fancyNumber': '222226'},
#     'playerColor': {'primary': '000000',
#      'number': '222226',
#      'outline': 'fff93d',
#      'fancyNumber': '222226'}}}},
#  'graph': {'match_id': 12531328,
#   'response_code': 404,
#   'data': {'error': {'code': 404, 'message': 'Not Found'}}},
#  'match_info': {'match_id': 12531328,
#   'response_code': 200,
#   'data': {'event': {'tournament': {'name': 'Frauen Bundesliga',
#      'slug': 'frauen-bundesliga',
#      'category': {'name': 'Austria',
#       'slug': 'austria',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 17,
#       'country': {'alpha2': 'AT',
#        'alpha3': 'AUT',
#        'name': 'Austria',
#        'slug': 'austria'},
#       'flag': 'austria',
#       'alpha2': 'AT'},
#      'uniqueTournament': {'name': 'Frauen Bundesliga',
#       'slug': 'frauen-bundesliga',
#       'primaryColorHex': '#cc0033',
#       'secondaryColorHex': '#ad536a',
#       'category': {'name': 'Austria',
#        'slug': 'austria',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 17,
#        'country': {'alpha2': 'AT',
#         'alpha3': 'AUT',
#         'name': 'Austria',
#         'slug': 'austria'},
#        'flag': 'austria',
#        'alpha2': 'AT'},
#       'userCount': 1053,
#       'id': 9415,
#       'country': {},
#       'hasPerformanceGraphFeature': False,
#       'hasEventPlayerStatistics': False,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'isGroup': False,
#      'competitionType': 1,
#      'isLive': False,
#      'id': 3718},
#     'season': {'name': 'Bundesliga, Women 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 63832},
#     'roundInfo': {'round': 6},
#     'customId': 'EEddsEGue',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'LASK',
#      'slug': 'lask',
#      'shortName': 'LASK',
#      'gender': 'F',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 97,
#      'nameCode': 'LAS',
#      'class': 0,
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 549079,
#      'country': {'alpha2': 'AT',
#       'alpha3': 'AUT',
#       'name': 'Austria',
#       'slug': 'austria'},
#      'subTeams': [],
#      'fullName': 'LASK',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'awayTeam': {'name': 'First Vienna',
#      'slug': 'first-vienna',
#      'shortName': 'First Vienna',
#      'gender': 'F',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 951,
#      'manager': {'name': 'Mark Dobrounig',
#       'slug': 'mark-dobrounig',
#       'shortName': 'M. Dobrounig',
#       'id': 806395,
#       'country': {'alpha2': 'AT',
#        'alpha3': 'AUT',
#        'name': 'Austria',
#        'slug': 'austria'}},
#      'venue': {'city': {'name': 'Vienna'},
#       'venueCoordinates': {'latitude': 48.248756, 'longitude': 16.359734},
#       'hidden': True,
#       'slug': 'stadion-hohe-warte',
#       'name': 'Stadion Hohe Warte',
#       'capacity': 5500,
#       'id': 1226,
#       'country': {'alpha2': 'AT',
#        'alpha3': 'AUT',
#        'name': 'Austria',
#        'slug': 'austria'},
#       'stadium': {'name': 'Stadion Hohe Warte', 'capacity': 5500}},
#      'nameCode': 'FIR',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 383979,
#      'country': {'alpha2': 'AT',
#       'alpha3': 'AUT',
#       'name': 'Austria',
#       'slug': 'austria'},
#      'subTeams': [],
#      'fullName': 'First Vienna',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'homeScore': {'current': 3,
#      'display': 3,
#      'period1': 1,
#      'period2': 2,
#      'normaltime': 3},
#     'awayScore': {'current': 2,
#      'display': 2,
#      'period1': 0,
#      'period2': 2,
#      'normaltime': 2},
#     'time': {'currentPeriodStartTimestamp': 1728133500,
#      'period1StartTimestamp': 1728129720,
#      'period2StartTimestamp': 1728133500},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime'],
#      'changeTimestamp': 1728136686},
#     'hasGlobalHighlights': False,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12531328,
#     'defaultPeriodCount': 2,
#     'defaultPeriodLength': 45,
#     'defaultOvertimeLength': 15,
#     'currentPeriodStartTimestamp': 1728133500,
#     'startTimestamp': 1728129600,
#     'slug': 'lask-first-vienna',
#     'finalResultOnly': False,
#     'feedLocked': True,
#     'fanRatingEvent': False,
#     'showTotoPromo': True,
#     'isEditor': False}}},
#  'odds': {'match_id': 12531328,
#   'response_code': 404,
#   'data': {'error': {'code': 404, 'message': 'Not Found'}}},
#  'pregame_form': {'match_id': 12531328,
#   'response_code': 200,
#   'data': {'homeTeam': {'position': 9,
#     'value': '3',
#     'form': ['L', 'L', 'L', 'W', 'L']},
#    'awayTeam': {'position': 5,
#     'value': '5',
#     'form': ['L', 'L', 'D', 'W', 'D']},
#    'label': 'Pts'}},
#  'statistics': {'match_id': 12531328,
#   'response_code': 404,
#   'data': {'error': {'code': 404, 'message': 'Not Found'}}}}

# %%
import http.client
import pandas as pd
import json
from datetime import datetime, timedelta
from analysis.models import MatchStats  # `MatchStats` modelini içe aktarın


class ResultAPI:
    def __init__(self, date="2023-01-01"):
        self.date = date
        self.full_df = pd.DataFrame()

    def AddDataBase(self):

            df = self.gunluk_fikstur()
            MatchStats.objects.filter(id__in=df['id'].tolist()).delete()
            
            fixture_list = [
                MatchStats(
                    id=row['id'],  # ID manuel olarak girilecek
                    tarih=row['tarih'],  # Tarih alanı ekleniyor
                    stats=row['Stats']  # JSON formatındaki veriyi 'stats' alanına ekle
                )
                for index, row in df.iterrows()
            ]
            
            MatchStats.objects.bulk_create(fixture_list)
            print("Mevcut veriler silindi ve yeni veriler eklendi.")
        
    def gunluk_fikstur(self):
        try:
            conn = http.client.HTTPSConnection('www.sofascore.com')
            conn.request(
                'GET',
                f'/api/v1/sport/football/scheduled-events/{self.date}'
            )
            response = conn.getresponse()
            data = response.read()
            data = json.loads(data)["events"]

            model_data = [{
                'tarih': self.date,
                'data': data,
              
            }]
            
            df = pd.DataFrame(model_data)
        except Exception as e:
            model_data = [{
                'tarih': self.date,
                'data': [],
                
            }]
        try:
            
            df = pd.DataFrame(model_data)
            df_exploded = df.explode('data')
            expanded_data = pd.json_normalize(df_exploded['data'])
            expanded_data['tarih'] = list(df_exploded['tarih'])
            data = expanded_data.drop_duplicates(subset='id', keep='last')
            data = data[data["status.type"] == "finished"]
            
            
        except:
            pass
        
   
        data_stat = []
        toplam = len(data)
        for idx in list(data["id"]):
            toplam = toplam-1
            
            try:
               
                sofa_api = SofaScoreAPI(idx)
                result_all = sofa_api.fetch_all_data()
                data_stat.append(result_all)
                print("{} işlem başarılı kalan işlem sayısı".format(toplam))
            except:
                print("{} işlem ERRORRRR kalan işlem sayısı".format(toplam))
                result_all = {}
                data_stat.append(result_all)
                
                
        data["Stats"] = data_stat

        columns = ['id','tarih','Stats']
        result_data = data[columns]

        return result_data
        
api = ResultAPI(date = "2024-10-02")
data  = api.AddDataBase()
data
# Out:
# 193 işlem başarılı kalan işlem sayısı
# 192 işlem başarılı kalan işlem sayısı
# 191 işlem başarılı kalan işlem sayısı
# 190 işlem başarılı kalan işlem sayısı
# 189 işlem başarılı kalan işlem sayısı
# 188 işlem başarılı kalan işlem sayısı
# 187 işlem ERRORRRR kalan işlem sayısı
# 186 işlem ERRORRRR kalan işlem sayısı
# 185 işlem ERRORRRR kalan işlem sayısı
# 184 işlem ERRORRRR kalan işlem sayısı
# 183 işlem ERRORRRR kalan işlem sayısı
# 182 işlem başarılı kalan işlem sayısı
# 181 işlem başarılı kalan işlem sayısı
# 180 işlem başarılı kalan işlem sayısı
# 179 işlem başarılı kalan işlem sayısı
# 178 işlem başarılı kalan işlem sayısı
# 177 işlem başarılı kalan işlem sayısı
# 176 işlem başarılı kalan işlem sayısı
# 175 işlem başarılı kalan işlem sayısı
# 174 işlem başarılı kalan işlem sayısı
# 173 işlem başarılı kalan işlem sayısı
# 172 işlem ERRORRRR kalan işlem sayısı
# 171 işlem ERRORRRR kalan işlem sayısı
# 170 işlem başarılı kalan işlem sayısı
# 169 işlem ERRORRRR kalan işlem sayısı
# 168 işlem başarılı kalan işlem sayısı
# 167 işlem başarılı kalan işlem sayısı
# 166 işlem ERRORRRR kalan işlem sayısı
# 165 işlem ERRORRRR kalan işlem sayısı
# 164 işlem başarılı kalan işlem sayısı
# 163 işlem başarılı kalan işlem sayısı
# 162 işlem başarılı kalan işlem sayısı
# 161 işlem başarılı kalan işlem sayısı
# 160 işlem başarılı kalan işlem sayısı
# 159 işlem başarılı kalan işlem sayısı
# 158 işlem başarılı kalan işlem sayısı
# 157 işlem başarılı kalan işlem sayısı
# 156 işlem başarılı kalan işlem sayısı
# 155 işlem başarılı kalan işlem sayısı
# 154 işlem başarılı kalan işlem sayısı
# 153 işlem başarılı kalan işlem sayısı
# 152 işlem başarılı kalan işlem sayısı
# 151 işlem başarılı kalan işlem sayısı
# 150 işlem ERRORRRR kalan işlem sayısı
# 149 işlem ERRORRRR kalan işlem sayısı
# 148 işlem ERRORRRR kalan işlem sayısı
# 147 işlem ERRORRRR kalan işlem sayısı
# 146 işlem ERRORRRR kalan işlem sayısı
# 145 işlem ERRORRRR kalan işlem sayısı
# 144 işlem ERRORRRR kalan işlem sayısı
# 143 işlem ERRORRRR kalan işlem sayısı
# 142 işlem ERRORRRR kalan işlem sayısı
# 141 işlem ERRORRRR kalan işlem sayısı
# 140 işlem ERRORRRR kalan işlem sayısı
# 139 işlem ERRORRRR kalan işlem sayısı
# 138 işlem ERRORRRR kalan işlem sayısı
# 137 işlem ERRORRRR kalan işlem sayısı
# 136 işlem ERRORRRR kalan işlem sayısı
# 135 işlem ERRORRRR kalan işlem sayısı
# 134 işlem ERRORRRR kalan işlem sayısı
# 133 işlem ERRORRRR kalan işlem sayısı
# 132 işlem ERRORRRR kalan işlem sayısı
# 131 işlem ERRORRRR kalan işlem sayısı
# 130 işlem ERRORRRR kalan işlem sayısı
# 129 işlem ERRORRRR kalan işlem sayısı
# 128 işlem ERRORRRR kalan işlem sayısı
# 127 işlem ERRORRRR kalan işlem sayısı
# 126 işlem ERRORRRR kalan işlem sayısı
# 125 işlem ERRORRRR kalan işlem sayısı
# 124 işlem ERRORRRR kalan işlem sayısı
# 123 işlem başarılı kalan işlem sayısı
# 122 işlem ERRORRRR kalan işlem sayısı
# 121 işlem ERRORRRR kalan işlem sayısı
# 120 işlem ERRORRRR kalan işlem sayısı
# 119 işlem ERRORRRR kalan işlem sayısı
# 118 işlem ERRORRRR kalan işlem sayısı
# 117 işlem ERRORRRR kalan işlem sayısı
# 116 işlem ERRORRRR kalan işlem sayısı
# 115 işlem ERRORRRR kalan işlem sayısı
# 114 işlem ERRORRRR kalan işlem sayısı
# 113 işlem ERRORRRR kalan işlem sayısı
# 112 işlem ERRORRRR kalan işlem sayısı
# 111 işlem ERRORRRR kalan işlem sayısı
# 110 işlem ERRORRRR kalan işlem sayısı
# 109 işlem ERRORRRR kalan işlem sayısı
# 108 işlem ERRORRRR kalan işlem sayısı
# 107 işlem ERRORRRR kalan işlem sayısı
# 106 işlem başarılı kalan işlem sayısı
# 105 işlem ERRORRRR kalan işlem sayısı
# 104 işlem ERRORRRR kalan işlem sayısı
# 103 işlem ERRORRRR kalan işlem sayısı
# 102 işlem ERRORRRR kalan işlem sayısı
# 101 işlem ERRORRRR kalan işlem sayısı
# 100 işlem ERRORRRR kalan işlem sayısı
# 99 işlem ERRORRRR kalan işlem sayısı
# 98 işlem ERRORRRR kalan işlem sayısı
# 97 işlem ERRORRRR kalan işlem sayısı
# 96 işlem ERRORRRR kalan işlem sayısı
# 95 işlem ERRORRRR kalan işlem sayısı
# 94 işlem ERRORRRR kalan işlem sayısı
# 93 işlem ERRORRRR kalan işlem sayısı
# 92 işlem ERRORRRR kalan işlem sayısı
# 91 işlem ERRORRRR kalan işlem sayısı
# 90 işlem ERRORRRR kalan işlem sayısı
# 89 işlem ERRORRRR kalan işlem sayısı
# 88 işlem ERRORRRR kalan işlem sayısı
# 87 işlem ERRORRRR kalan işlem sayısı
# 86 işlem ERRORRRR kalan işlem sayısı
# 85 işlem ERRORRRR kalan işlem sayısı
# 84 işlem ERRORRRR kalan işlem sayısı
# 83 işlem ERRORRRR kalan işlem sayısı
# 82 işlem ERRORRRR kalan işlem sayısı
# 81 işlem başarılı kalan işlem sayısı
# 80 işlem ERRORRRR kalan işlem sayısı
# 79 işlem ERRORRRR kalan işlem sayısı
# 78 işlem ERRORRRR kalan işlem sayısı
# 77 işlem ERRORRRR kalan işlem sayısı
# 76 işlem ERRORRRR kalan işlem sayısı
# 75 işlem ERRORRRR kalan işlem sayısı
# 74 işlem ERRORRRR kalan işlem sayısı
# 73 işlem ERRORRRR kalan işlem sayısı
# 72 işlem ERRORRRR kalan işlem sayısı
# 71 işlem başarılı kalan işlem sayısı
# 70 işlem ERRORRRR kalan işlem sayısı
# 69 işlem ERRORRRR kalan işlem sayısı
# 68 işlem başarılı kalan işlem sayısı
# 67 işlem ERRORRRR kalan işlem sayısı
# 66 işlem başarılı kalan işlem sayısı
# 65 işlem başarılı kalan işlem sayısı
# 64 işlem başarılı kalan işlem sayısı
# 63 işlem başarılı kalan işlem sayısı
# 62 işlem başarılı kalan işlem sayısı
# 61 işlem başarılı kalan işlem sayısı
# 60 işlem başarılı kalan işlem sayısı
# 59 işlem başarılı kalan işlem sayısı
# 58 işlem başarılı kalan işlem sayısı
# 57 işlem başarılı kalan işlem sayısı
# 56 işlem başarılı kalan işlem sayısı
# 55 işlem başarılı kalan işlem sayısı
# 54 işlem başarılı kalan işlem sayısı
# 53 işlem başarılı kalan işlem sayısı
# 52 işlem başarılı kalan işlem sayısı
# 51 işlem başarılı kalan işlem sayısı
# 50 işlem başarılı kalan işlem sayısı
# 49 işlem başarılı kalan işlem sayısı
# 48 işlem başarılı kalan işlem sayısı
# 47 işlem ERRORRRR kalan işlem sayısı
# 46 işlem başarılı kalan işlem sayısı
# 45 işlem başarılı kalan işlem sayısı
# 44 işlem başarılı kalan işlem sayısı
# 43 işlem ERRORRRR kalan işlem sayısı
# 42 işlem başarılı kalan işlem sayısı
# 41 işlem başarılı kalan işlem sayısı
# 40 işlem başarılı kalan işlem sayısı
# 39 işlem başarılı kalan işlem sayısı
# 38 işlem başarılı kalan işlem sayısı
# 37 işlem başarılı kalan işlem sayısı
# 36 işlem başarılı kalan işlem sayısı
# 35 işlem başarılı kalan işlem sayısı
# 34 işlem başarılı kalan işlem sayısı
# 33 işlem başarılı kalan işlem sayısı
# 32 işlem başarılı kalan işlem sayısı
# 31 işlem başarılı kalan işlem sayısı
# 30 işlem başarılı kalan işlem sayısı
# 29 işlem ERRORRRR kalan işlem sayısı
# 28 işlem başarılı kalan işlem sayısı
# 27 işlem başarılı kalan işlem sayısı
# 26 işlem başarılı kalan işlem sayısı
# 25 işlem ERRORRRR kalan işlem sayısı
# 24 işlem başarılı kalan işlem sayısı
# 23 işlem ERRORRRR kalan işlem sayısı
# 22 işlem ERRORRRR kalan işlem sayısı
# 21 işlem başarılı kalan işlem sayısı
# 20 işlem başarılı kalan işlem sayısı
# 19 işlem başarılı kalan işlem sayısı
# 18 işlem başarılı kalan işlem sayısı
# 17 işlem başarılı kalan işlem sayısı
# 16 işlem başarılı kalan işlem sayısı
# 15 işlem başarılı kalan işlem sayısı
# 14 işlem başarılı kalan işlem sayısı
# 13 işlem başarılı kalan işlem sayısı
# 12 işlem başarılı kalan işlem sayısı
# 11 işlem başarılı kalan işlem sayısı
# 10 işlem başarılı kalan işlem sayısı
# 9 işlem başarılı kalan işlem sayısı
# 8 işlem başarılı kalan işlem sayısı
# 7 işlem başarılı kalan işlem sayısı
# 6 işlem başarılı kalan işlem sayısı
# 5 işlem ERRORRRR kalan işlem sayısı
# 4 işlem başarılı kalan işlem sayısı
# 3 işlem ERRORRRR kalan işlem sayısı
# 2 işlem başarılı kalan işlem sayısı
# 1 işlem başarılı kalan işlem sayısı
# 0 işlem başarılı kalan işlem sayısı
# Mevcut veriler silindi ve yeni veriler eklendi.
