# %%
import os
import django
import pandas as pd
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'fxfutbol.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from analysis.models import MatchStats
fixture_data = MatchStats.objects.all().values()
df = pd.DataFrame(list(fixture_data))
df
# Out:
#            id       tarih                                              stats  \
# 0    11907427  2024-10-07  {'match_id': 11907427, 'lineups': {'match_id':...
# 1    11907428  2024-10-07  {'match_id': 11907428, 'lineups': {'match_id':...
# 2    11907429  2024-10-06  {'match_id': 11907429, 'lineups': {'match_id':...
# 3    11907430  2024-10-07  {'match_id': 11907430, 'lineups': {'match_id':...
# 4    11907432  2024-10-07  {'match_id': 11907432, 'lineups': {'match_id':...
# ..        ...         ...                                                ...
# 834  12947741  2024-10-06  {'match_id': 12947741, 'lineups': {'match_id':...
# 835  12959814  2024-10-09  {'match_id': 12959814, 'lineups': {'match_id':...
# 836  12962059  2024-10-09  {'match_id': 12962059, 'lineups': {'match_id':...
# 837  12962060  2024-10-09  {'match_id': 12962060, 'lineups': {'match_id':...
# 838  12962061  2024-10-09  {'match_id': 12962061, 'lineups': {'match_id':...
#
#                          update_date
# 0   2024-10-09 22:07:48.850918+00:00
# 1   2024-10-09 22:07:48.851376+00:00
# 2   2024-10-09 21:56:06.245948+00:00
# 3   2024-10-09 22:07:48.852800+00:00
# 4   2024-10-09 22:07:48.851819+00:00
# ..                               ...
# 834 2024-10-09 21:56:06.489706+00:00
# 835 2024-10-09 21:25:32.245929+00:00
# 836 2024-10-09 21:25:32.245663+00:00
# 837 2024-10-09 21:25:32.245840+00:00
# 838 2024-10-09 21:25:32.245882+00:00
#
# [839 rows x 4 columns]

# %%
df["stats"][0].keys()
# Out:
# dict_keys(['match_id', 'lineups', 'incidents', 'graph', 'match_info', 'odds', 'pregame_form', 'statistics'])

# %%
stats_df = pd.json_normalize(df['stats'])

stats_df
# Out:
#      match_id  lineups.match_id  lineups.response_code lineups.data.confirmed  \
# 0    11907427          11907427                    200                   True
# 1    11907428          11907428                    200                   True
# 2    11907429          11907429                    200                   True
# 3    11907430          11907430                    200                   True
# 4    11907432          11907432                    200                   True
# ..        ...               ...                    ...                    ...
# 834  12947741          12947741                    404                    NaN
# 835  12959814          12959814                    404                    NaN
# 836  12962059          12962059                    200                   True
# 837  12962060          12962060                    200                   True
# 838  12962061          12962061                    404                    NaN
#
#                              lineups.data.home.players  \
# 0    [{'player': {'name': 'Kristoffer Nordfeldt', '...
# 1    [{'player': {'name': 'Oscar Jansson', 'slug': ...
# 2    [{'player': {'name': 'Warner Hahn', 'firstName...
# 3    [{'player': {'name': 'Ricardo Friedrich', 'slu...
# 4    [{'player': {'name': 'David Mitov Nilsson', 's...
# ..                                                 ...
# 834                                                NaN
# 835                                                NaN
# 836  [{'player': {'name': 'Rafael Munteanu', 'first...
# 837  [{'player': {'name': 'Konstantin Heide', 'firs...
# 838                                                NaN
#
#     lineups.data.home.supportStaff lineups.data.home.formation  \
# 0                               []                       5-4-1
# 1                               []                     4-2-3-1
# 2                               []                     4-2-3-1
# 3                               []                       4-4-2
# 4                               []                     4-2-3-1
# ..                             ...                         ...
# 834                            NaN                         NaN
# 835                            NaN                         NaN
# 836                             []                       4-3-3
# 837                             []                       4-3-3
# 838                            NaN                         NaN
#
#     lineups.data.home.playerColor.primary  \
# 0                                  000000
# 1                                  132845
# 2                                  ffffff
# 3                                  79bcff
# 4                                  fcfcfd
# ..                                    ...
# 834                                   NaN
# 835                                   NaN
# 836                                ff0000
# 837                                ffffff
# 838                                   NaN
#
#     lineups.data.home.playerColor.number  \
# 0                                 ffff00
# 1                                 5ed9ff
# 2                                 008000
# 3                                 ffffff
# 4                                 0000ff
# ..                                   ...
# 834                                  NaN
# 835                                  NaN
# 836                               ffff00
# 837                               000000
# 838                                  NaN
#
#     lineups.data.home.playerColor.outline  ...  \
# 0                                  000000  ...
# 1                                  132845  ...
# 2                                  ffffff  ...
# 3                                  79bcff  ...
# 4                                  fcfcfd  ...
# ..                                    ...  ...
# 834                                   NaN  ...
# 835                                   NaN  ...
# 836                                ff0000  ...
# 837                                ffffff  ...
# 838                                   NaN  ...
#
#     match_info.data.event.awayScore.penalties  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 834                                       NaN
# 835                                       NaN
# 836                                       NaN
# 837                                       NaN
# 838                                       NaN
#
#     match_info.data.event.awayTeam.createdByEditor  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 834                                            NaN
# 835                                            NaN
# 836                                            NaN
# 837                                            NaN
# 838                                            NaN
#
#     match_info.data.event.tournament.roundPrefix  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 834                                          NaN
# 835                                          NaN
# 836                                          NaN
# 837                                          NaN
# 838                                          NaN
#
#     match_info.data.event.homeScore.extra1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 834                                    NaN
# 835                                    NaN
# 836                                    NaN
# 837                                    NaN
# 838                                    NaN
#
#     match_info.data.event.homeScore.extra2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 834                                    NaN
# 835                                    NaN
# 836                                    NaN
# 837                                    NaN
# 838                                    NaN
#
#     match_info.data.event.awayScore.extra1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 834                                    NaN
# 835                                    NaN
# 836                                    NaN
# 837                                    NaN
# 838                                    NaN
#
#     match_info.data.event.awayScore.extra2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 834                                    NaN
# 835                                    NaN
# 836                                    NaN
# 837                                    NaN
# 838                                    NaN
#
#     match_info.data.event.time.extra1StartTimestamp  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 834                                             NaN
# 835                                             NaN
# 836                                             NaN
# 837                                             NaN
# 838                                             NaN
#
#     match_info.data.event.time.extra2StartTimestamp  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 834                                             NaN
# 835                                             NaN
# 836                                             NaN
# 837                                             NaN
# 838                                             NaN
#
#     match_info.data.event.aggregatedWinnerCode
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 834                                        NaN
# 835                                        NaN
# 836                                        NaN
# 837                                        NaN
# 838                                        NaN
#
# [839 rows x 347 columns]

# %%
columns = list(stats_df.columns)

# %%
match_columns = [col for col in columns if col.startswith("match")]
match_columns
# Out:
# ['match_id',
#  'match_info.match_id',
#  'match_info.response_code',
#  'match_info.data.event.tournament.name',
#  'match_info.data.event.tournament.slug',
#  'match_info.data.event.tournament.category.name',
#  'match_info.data.event.tournament.category.slug',
#  'match_info.data.event.tournament.category.sport.name',
#  'match_info.data.event.tournament.category.sport.slug',
#  'match_info.data.event.tournament.category.sport.id',
#  'match_info.data.event.tournament.category.id',
#  'match_info.data.event.tournament.category.country.alpha2',
#  'match_info.data.event.tournament.category.country.alpha3',
#  'match_info.data.event.tournament.category.country.name',
#  'match_info.data.event.tournament.category.country.slug',
#  'match_info.data.event.tournament.category.flag',
#  'match_info.data.event.tournament.category.alpha2',
#  'match_info.data.event.tournament.uniqueTournament.name',
#  'match_info.data.event.tournament.uniqueTournament.slug',
#  'match_info.data.event.tournament.uniqueTournament.primaryColorHex',
#  'match_info.data.event.tournament.uniqueTournament.secondaryColorHex',
#  'match_info.data.event.tournament.uniqueTournament.category.name',
#  'match_info.data.event.tournament.uniqueTournament.category.slug',
#  'match_info.data.event.tournament.uniqueTournament.category.sport.name',
#  'match_info.data.event.tournament.uniqueTournament.category.sport.slug',
#  'match_info.data.event.tournament.uniqueTournament.category.sport.id',
#  'match_info.data.event.tournament.uniqueTournament.category.id',
#  'match_info.data.event.tournament.uniqueTournament.category.country.alpha2',
#  'match_info.data.event.tournament.uniqueTournament.category.country.alpha3',
#  'match_info.data.event.tournament.uniqueTournament.category.country.name',
#  'match_info.data.event.tournament.uniqueTournament.category.country.slug',
#  'match_info.data.event.tournament.uniqueTournament.category.flag',
#  'match_info.data.event.tournament.uniqueTournament.category.alpha2',
#  'match_info.data.event.tournament.uniqueTournament.userCount',
#  'match_info.data.event.tournament.uniqueTournament.id',
#  'match_info.data.event.tournament.uniqueTournament.hasPerformanceGraphFeature',
#  'match_info.data.event.tournament.uniqueTournament.hasEventPlayerStatistics',
#  'match_info.data.event.tournament.uniqueTournament.displayInverseHomeAwayTeams',
#  'match_info.data.event.tournament.priority',
#  'match_info.data.event.tournament.isGroup',
#  'match_info.data.event.tournament.competitionType',
#  'match_info.data.event.tournament.isLive',
#  'match_info.data.event.tournament.id',
#  'match_info.data.event.season.name',
#  'match_info.data.event.season.year',
#  'match_info.data.event.season.editor',
#  'match_info.data.event.season.id',
#  'match_info.data.event.roundInfo.round',
#  'match_info.data.event.customId',
#  'match_info.data.event.status.code',
#  'match_info.data.event.status.description',
#  'match_info.data.event.status.type',
#  'match_info.data.event.winnerCode',
#  'match_info.data.event.venue.city.name',
#  'match_info.data.event.venue.venueCoordinates.latitude',
#  'match_info.data.event.venue.venueCoordinates.longitude',
#  'match_info.data.event.venue.hidden',
#  'match_info.data.event.venue.slug',
#  'match_info.data.event.venue.name',
#  'match_info.data.event.venue.capacity',
#  'match_info.data.event.venue.id',
#  'match_info.data.event.venue.country.alpha2',
#  'match_info.data.event.venue.country.alpha3',
#  'match_info.data.event.venue.country.name',
#  'match_info.data.event.venue.country.slug',
#  'match_info.data.event.venue.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.venue.stadium.name',
#  'match_info.data.event.venue.stadium.capacity',
#  'match_info.data.event.referee.name',
#  'match_info.data.event.referee.slug',
#  'match_info.data.event.referee.yellowCards',
#  'match_info.data.event.referee.redCards',
#  'match_info.data.event.referee.yellowRedCards',
#  'match_info.data.event.referee.games',
#  'match_info.data.event.referee.sport.id',
#  'match_info.data.event.referee.sport.slug',
#  'match_info.data.event.referee.sport.name',
#  'match_info.data.event.referee.id',
#  'match_info.data.event.referee.country.alpha2',
#  'match_info.data.event.referee.country.alpha3',
#  'match_info.data.event.referee.country.name',
#  'match_info.data.event.referee.country.slug',
#  'match_info.data.event.homeTeam.name',
#  'match_info.data.event.homeTeam.slug',
#  'match_info.data.event.homeTeam.shortName',
#  'match_info.data.event.homeTeam.gender',
#  'match_info.data.event.homeTeam.sport.name',
#  'match_info.data.event.homeTeam.sport.slug',
#  'match_info.data.event.homeTeam.sport.id',
#  'match_info.data.event.homeTeam.userCount',
#  'match_info.data.event.homeTeam.manager.name',
#  'match_info.data.event.homeTeam.manager.slug',
#  'match_info.data.event.homeTeam.manager.shortName',
#  'match_info.data.event.homeTeam.manager.id',
#  'match_info.data.event.homeTeam.manager.country.alpha2',
#  'match_info.data.event.homeTeam.manager.country.alpha3',
#  'match_info.data.event.homeTeam.manager.country.name',
#  'match_info.data.event.homeTeam.manager.country.slug',
#  'match_info.data.event.homeTeam.manager.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.homeTeam.manager.fieldTranslations.shortNameTranslation.ar',
#  'match_info.data.event.homeTeam.venue.city.name',
#  'match_info.data.event.homeTeam.venue.venueCoordinates.latitude',
#  'match_info.data.event.homeTeam.venue.venueCoordinates.longitude',
#  'match_info.data.event.homeTeam.venue.hidden',
#  'match_info.data.event.homeTeam.venue.slug',
#  'match_info.data.event.homeTeam.venue.name',
#  'match_info.data.event.homeTeam.venue.capacity',
#  'match_info.data.event.homeTeam.venue.id',
#  'match_info.data.event.homeTeam.venue.country.alpha2',
#  'match_info.data.event.homeTeam.venue.country.alpha3',
#  'match_info.data.event.homeTeam.venue.country.name',
#  'match_info.data.event.homeTeam.venue.country.slug',
#  'match_info.data.event.homeTeam.venue.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.homeTeam.venue.stadium.name',
#  'match_info.data.event.homeTeam.venue.stadium.capacity',
#  'match_info.data.event.homeTeam.nameCode',
#  'match_info.data.event.homeTeam.class',
#  'match_info.data.event.homeTeam.disabled',
#  'match_info.data.event.homeTeam.national',
#  'match_info.data.event.homeTeam.type',
#  'match_info.data.event.homeTeam.id',
#  'match_info.data.event.homeTeam.country.alpha2',
#  'match_info.data.event.homeTeam.country.alpha3',
#  'match_info.data.event.homeTeam.country.name',
#  'match_info.data.event.homeTeam.country.slug',
#  'match_info.data.event.homeTeam.subTeams',
#  'match_info.data.event.homeTeam.fullName',
#  'match_info.data.event.homeTeam.teamColors.primary',
#  'match_info.data.event.homeTeam.teamColors.secondary',
#  'match_info.data.event.homeTeam.teamColors.text',
#  'match_info.data.event.homeTeam.foundationDateTimestamp',
#  'match_info.data.event.homeTeam.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.homeTeam.fieldTranslations.nameTranslation.ru',
#  'match_info.data.event.awayTeam.name',
#  'match_info.data.event.awayTeam.slug',
#  'match_info.data.event.awayTeam.shortName',
#  'match_info.data.event.awayTeam.gender',
#  'match_info.data.event.awayTeam.sport.name',
#  'match_info.data.event.awayTeam.sport.slug',
#  'match_info.data.event.awayTeam.sport.id',
#  'match_info.data.event.awayTeam.userCount',
#  'match_info.data.event.awayTeam.manager.name',
#  'match_info.data.event.awayTeam.manager.slug',
#  'match_info.data.event.awayTeam.manager.shortName',
#  'match_info.data.event.awayTeam.manager.id',
#  'match_info.data.event.awayTeam.manager.country.alpha2',
#  'match_info.data.event.awayTeam.manager.country.alpha3',
#  'match_info.data.event.awayTeam.manager.country.name',
#  'match_info.data.event.awayTeam.manager.country.slug',
#  'match_info.data.event.awayTeam.venue.city.name',
#  'match_info.data.event.awayTeam.venue.venueCoordinates.latitude',
#  'match_info.data.event.awayTeam.venue.venueCoordinates.longitude',
#  'match_info.data.event.awayTeam.venue.hidden',
#  'match_info.data.event.awayTeam.venue.slug',
#  'match_info.data.event.awayTeam.venue.name',
#  'match_info.data.event.awayTeam.venue.capacity',
#  'match_info.data.event.awayTeam.venue.id',
#  'match_info.data.event.awayTeam.venue.country.alpha2',
#  'match_info.data.event.awayTeam.venue.country.alpha3',
#  'match_info.data.event.awayTeam.venue.country.name',
#  'match_info.data.event.awayTeam.venue.country.slug',
#  'match_info.data.event.awayTeam.venue.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.awayTeam.venue.stadium.name',
#  'match_info.data.event.awayTeam.venue.stadium.capacity',
#  'match_info.data.event.awayTeam.nameCode',
#  'match_info.data.event.awayTeam.class',
#  'match_info.data.event.awayTeam.disabled',
#  'match_info.data.event.awayTeam.national',
#  'match_info.data.event.awayTeam.type',
#  'match_info.data.event.awayTeam.id',
#  'match_info.data.event.awayTeam.country.alpha2',
#  'match_info.data.event.awayTeam.country.alpha3',
#  'match_info.data.event.awayTeam.country.name',
#  'match_info.data.event.awayTeam.country.slug',
#  'match_info.data.event.awayTeam.subTeams',
#  'match_info.data.event.awayTeam.fullName',
#  'match_info.data.event.awayTeam.teamColors.primary',
#  'match_info.data.event.awayTeam.teamColors.secondary',
#  'match_info.data.event.awayTeam.teamColors.text',
#  'match_info.data.event.awayTeam.foundationDateTimestamp',
#  'match_info.data.event.awayTeam.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.awayTeam.fieldTranslations.nameTranslation.ru',
#  'match_info.data.event.homeScore.current',
#  'match_info.data.event.homeScore.display',
#  'match_info.data.event.homeScore.period1',
#  'match_info.data.event.homeScore.period2',
#  'match_info.data.event.homeScore.normaltime',
#  'match_info.data.event.awayScore.current',
#  'match_info.data.event.awayScore.display',
#  'match_info.data.event.awayScore.period1',
#  'match_info.data.event.awayScore.period2',
#  'match_info.data.event.awayScore.normaltime',
#  'match_info.data.event.time.injuryTime1',
#  'match_info.data.event.time.injuryTime2',
#  'match_info.data.event.time.currentPeriodStartTimestamp',
#  'match_info.data.event.changes.changes',
#  'match_info.data.event.changes.changeTimestamp',
#  'match_info.data.event.hasGlobalHighlights',
#  'match_info.data.event.hasEventPlayerStatistics',
#  'match_info.data.event.hasEventPlayerHeatMap',
#  'match_info.data.event.detailId',
#  'match_info.data.event.crowdsourcingDataDisplayEnabled',
#  'match_info.data.event.id',
#  'match_info.data.event.defaultPeriodCount',
#  'match_info.data.event.defaultPeriodLength',
#  'match_info.data.event.defaultOvertimeLength',
#  'match_info.data.event.currentPeriodStartTimestamp',
#  'match_info.data.event.startTimestamp',
#  'match_info.data.event.slug',
#  'match_info.data.event.finalResultOnly',
#  'match_info.data.event.feedLocked',
#  'match_info.data.event.fanRatingEvent',
#  'match_info.data.event.seasonStatisticsType',
#  'match_info.data.event.showTotoPromo',
#  'match_info.data.event.isEditor',
#  'match_info.data.event.hasBet365LiveStream',
#  'match_info.data.event.bet365ExcludedCountryCodes',
#  'match_info.data.event.attendance',
#  'match_info.data.event.awayTeam.manager.fieldTranslations.nameTranslation.ar',
#  'match_info.data.event.awayTeam.manager.fieldTranslations.shortNameTranslation.ar',
#  'match_info.data.event.time.period1StartTimestamp',
#  'match_info.data.event.time.period2StartTimestamp',
#  'match_info.data.event.hasXg',
#  'match_info.data.event.awayRedCards',
#  'match_info.data.event.homeRedCards',
#  'match_info.data.event.streamContentId',
#  'match_info.data.event.season.seasonCoverageInfo.editorCoverageLevel',
#  'match_info.data.event.roundInfo.name',
#  'match_info.data.event.roundInfo.slug',
#  'match_info.data.event.roundInfo.cupRoundType',
#  'match_info.data.event.cupMatchesInRound',
#  'match_info.data.event.homeScore.overtime',
#  'match_info.data.event.awayScore.overtime',
#  'match_info.data.event.time.injuryTime3',
#  'match_info.data.event.time.injuryTime4',
#  'match_info.data.event.homeTeam.createdByEditor',
#  'match_info.data.event.tournament.groupName',
#  'match_info.data.event.homeScore.penalties',
#  'match_info.data.event.awayScore.penalties',
#  'match_info.data.event.awayTeam.createdByEditor',
#  'match_info.data.event.tournament.roundPrefix',
#  'match_info.data.event.homeScore.extra1',
#  'match_info.data.event.homeScore.extra2',
#  'match_info.data.event.awayScore.extra1',
#  'match_info.data.event.awayScore.extra2',
#  'match_info.data.event.time.extra1StartTimestamp',
#  'match_info.data.event.time.extra2StartTimestamp',
#  'match_info.data.event.aggregatedWinnerCode']

# %%
mycols = [


  
    "match_id",
    "match_info.data.event.tournament.name",
    "match_info.data.event.tournament.category.name",
    "match_info.data.event.tournament.category.id",
    "match_info.data.event.tournament.category.country.alpha3",
    "match_info.data.event.tournament.uniqueTournament.id",
    "match_info.data.event.tournament.isGroup",
    "match_info.data.event.tournament.id",
    "match_info.data.event.season.name",
    "match_info.data.event.season.year",
    "match_info.data.event.season.id",
    "match_info.data.event.roundInfo.round",
    "match_info.data.event.customId",
    "match_info.data.event.homeTeam.name",
    "match_info.data.event.homeTeam.userCount",
    "match_info.data.event.homeTeam.manager.name",
    "match_info.data.event.homeTeam.id",
    "match_info.data.event.awayTeam.name",
    "match_info.data.event.awayTeam.userCount",
    "match_info.data.event.awayTeam.manager.name",
    "match_info.data.event.awayTeam.id",
    "match_info.data.event.homeScore.period1",
    "match_info.data.event.homeScore.period2",
    "match_info.data.event.homeScore.normaltime",
    "match_info.data.event.awayScore.period1",
    "match_info.data.event.awayScore.period2",
    "match_info.data.event.awayScore.normaltime",
    "match_info.data.event.hasGlobalHighlights",
    "match_info.data.event.hasEventPlayerStatistics",
    "match_info.data.event.hasEventPlayerHeatMap",
    "match_info.data.event.startTimestamp",
    "match_info.data.event.slug",
    "match_info.data.event.roundInfo.name",
    "match_info.data.event.roundInfo.slug"
]

# %%
stats_df[mycols].to_excel("Match_Son_Cols.xlsx")

# %%
mynewstats = stats_df[mycols]
mynewstats
# Out:
#      match_id match_info.data.event.tournament.name  \
# 0    11907427                           Allsvenskan
# 1    11907428                           Allsvenskan
# 2    11907429                           Allsvenskan
# 3    11907430                           Allsvenskan
# 4    11907432                           Allsvenskan
# ..        ...                                   ...
# 834  12947741                   Club Friendly Games
# 835  12959814                    U19 Friendly Games
# 836  12962059                    U19 Friendly Games
# 837  12962060                    U19 Friendly Games
# 838  12962061                    U19 Friendly Games
#
#     match_info.data.event.tournament.category.name  \
# 0                                           Sweden
# 1                                           Sweden
# 2                                           Sweden
# 3                                           Sweden
# 4                                           Sweden
# ..                                             ...
# 834                                          World
# 835                                          World
# 836                                          World
# 837                                          World
# 838                                          World
#
#      match_info.data.event.tournament.category.id  \
# 0                                               9
# 1                                               9
# 2                                               9
# 3                                               9
# 4                                               9
# ..                                            ...
# 834                                          1468
# 835                                          1468
# 836                                          1468
# 837                                          1468
# 838                                          1468
#
#     match_info.data.event.tournament.category.country.alpha3  \
# 0                                                  SWE
# 1                                                  SWE
# 2                                                  SWE
# 3                                                  SWE
# 4                                                  SWE
# ..                                                 ...
# 834                                                NaN
# 835                                                NaN
# 836                                                NaN
# 837                                                NaN
# 838                                                NaN
#
#      match_info.data.event.tournament.uniqueTournament.id  \
# 0                                                   40
# 1                                                   40
# 2                                                   40
# 3                                                   40
# 4                                                   40
# ..                                                 ...
# 834                                                853
# 835                                                856
# 836                                                856
# 837                                                856
# 838                                                856
#
#      match_info.data.event.tournament.isGroup  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 834                                     False
# 835                                     False
# 836                                     False
# 837                                     False
# 838                                     False
#
#      match_info.data.event.tournament.id match_info.data.event.season.name  \
# 0                                     24                  Allsvenskan 2024
# 1                                     24                  Allsvenskan 2024
# 2                                     24                  Allsvenskan 2024
# 3                                     24                  Allsvenskan 2024
# 4                                     24                  Allsvenskan 2024
# ..                                   ...                               ...
# 834                                   86          Club Friendly Games 2024
# 835                                 5799           U19 Friendly Games 2024
# 836                                 5799           U19 Friendly Games 2024
# 837                                 5799           U19 Friendly Games 2024
# 838                                 5799           U19 Friendly Games 2024
#
#     match_info.data.event.season.year  ...  \
# 0                                2024  ...
# 1                                2024  ...
# 2                                2024  ...
# 3                                2024  ...
# 4                                2024  ...
# ..                                ...  ...
# 834                              2024  ...
# 835                              2024  ...
# 836                              2024  ...
# 837                              2024  ...
# 838                              2024  ...
#
#      match_info.data.event.awayScore.period1  \
# 0                                          0
# 1                                          1
# 2                                          0
# 3                                          0
# 4                                          1
# ..                                       ...
# 834                                        1
# 835                                        1
# 836                                        2
# 837                                        1
# 838                                        0
#
#      match_info.data.event.awayScore.period2  \
# 0                                        2.0
# 1                                        0.0
# 2                                        0.0
# 3                                        1.0
# 4                                        1.0
# ..                                       ...
# 834                                      0.0
# 835                                      1.0
# 836                                      0.0
# 837                                      0.0
# 838                                      1.0
#
#     match_info.data.event.awayScore.normaltime  \
# 0                                          2.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          2.0
# ..                                         ...
# 834                                        1.0
# 835                                        2.0
# 836                                        2.0
# 837                                        1.0
# 838                                        1.0
#
#     match_info.data.event.hasGlobalHighlights  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 834                                     False
# 835                                     False
# 836                                     False
# 837                                     False
# 838                                     False
#
#      match_info.data.event.hasEventPlayerStatistics  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
# ..                                              ...
# 834                                             NaN
# 835                                             NaN
# 836                                             NaN
# 837                                             NaN
# 838                                             NaN
#
#     match_info.data.event.hasEventPlayerHeatMap  \
# 0                                          True
# 1                                          True
# 2                                          True
# 3                                          True
# 4                                          True
# ..                                          ...
# 834                                         NaN
# 835                                         NaN
# 836                                         NaN
# 837                                         NaN
# 838                                         NaN
#
#      match_info.data.event.startTimestamp  \
# 0                              1728216000
# 1                              1728216000
# 2                              1728133200
# 3                              1728225000
# 4                              1728225000
# ..                                    ...
# 834                            1728151200
# 835                            1728479700
# 836                            1728460800
# 837                            1728475200
# 838                            1728478800
#
#               match_info.data.event.slug  \
# 0                          aik-bk-hacken
# 1               kalmar-ff-djurgardens-if
# 2               halmstads-bk-hammarby-if
# 3                   malmo-ff-ifk-varnamo
# 4            ifk-norrkoping-ifk-goteborg
# ..                                   ...
# 834  coban-imperial-deportivo-malacateco
# 835               ireland-u19-greece-u19
# 836               romania-u19-norway-u19
# 837                spain-u19-germany-u19
# 838               france-u19-denmark-u19
#
#      match_info.data.event.roundInfo.name match_info.data.event.roundInfo.slug
# 0                                     NaN                                  NaN
# 1                                     NaN                                  NaN
# 2                                     NaN                                  NaN
# 3                                     NaN                                  NaN
# 4                                     NaN                                  NaN
# ..                                    ...                                  ...
# 834                                   NaN                                  NaN
# 835                                   NaN                                  NaN
# 836                                   NaN                                  NaN
# 837                                   NaN                                  NaN
# 838                                   NaN                                  NaN
#
# [839 rows x 34 columns]

# %%
mynewcols = ["match_id", "tournament_name", "tournament_category_name", "tournament_category_id", 
 "tournament_category_country_code", "unique_tournament_id", "tournament_is_group",
 "tournament_id", "season_name", "season_year", "season_id", "round_info", "custom_id", 
 "home_team_name", "home_team_user_count", "home_team_manager_name", "home_team_id", 
 "away_team_name", "away_team_user_count", "away_team_manager_name", "away_team_id", 
 "home_score_period1", "home_score_period2", "home_score_normaltime", "away_score_period1", 
 "away_score_period2", "away_score_normaltime", "has_global_highlights", "has_event_player_statistics",
 "has_event_player_heat_map", "start_timestamp", "event_slug", "round_info_name", "round_info_slug"]

mynewstats.columns = mynewcols


matchdata = mynewstats
matchdata

matchdata['start_timestamp'] = pd.to_datetime(matchdata['start_timestamp'], unit='s', errors='coerce')
matchdata = matchdata.fillna(0)
matchdata
# Out:
# /tmp/ipykernel_5659/493801923.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchdata['start_timestamp'] = pd.to_datetime(matchdata['start_timestamp'], unit='s', errors='coerce')
#      match_id      tournament_name tournament_category_name  \
# 0    11907427          Allsvenskan                   Sweden
# 1    11907428          Allsvenskan                   Sweden
# 2    11907429          Allsvenskan                   Sweden
# 3    11907430          Allsvenskan                   Sweden
# 4    11907432          Allsvenskan                   Sweden
# ..        ...                  ...                      ...
# 834  12947741  Club Friendly Games                    World
# 835  12959814   U19 Friendly Games                    World
# 836  12962059   U19 Friendly Games                    World
# 837  12962060   U19 Friendly Games                    World
# 838  12962061   U19 Friendly Games                    World
#
#      tournament_category_id tournament_category_country_code  \
# 0                         9                              SWE
# 1                         9                              SWE
# 2                         9                              SWE
# 3                         9                              SWE
# 4                         9                              SWE
# ..                      ...                              ...
# 834                    1468                                0
# 835                    1468                                0
# 836                    1468                                0
# 837                    1468                                0
# 838                    1468                                0
#
#      unique_tournament_id  tournament_is_group  tournament_id  \
# 0                      40                False             24
# 1                      40                False             24
# 2                      40                False             24
# 3                      40                False             24
# 4                      40                False             24
# ..                    ...                  ...            ...
# 834                   853                False             86
# 835                   856                False           5799
# 836                   856                False           5799
# 837                   856                False           5799
# 838                   856                False           5799
#
#                   season_name season_year  ...  away_score_period1  \
# 0            Allsvenskan 2024        2024  ...                   0
# 1            Allsvenskan 2024        2024  ...                   1
# 2            Allsvenskan 2024        2024  ...                   0
# 3            Allsvenskan 2024        2024  ...                   0
# 4            Allsvenskan 2024        2024  ...                   1
# ..                        ...         ...  ...                 ...
# 834  Club Friendly Games 2024        2024  ...                   1
# 835   U19 Friendly Games 2024        2024  ...                   1
# 836   U19 Friendly Games 2024        2024  ...                   2
# 837   U19 Friendly Games 2024        2024  ...                   1
# 838   U19 Friendly Games 2024        2024  ...                   0
#
#      away_score_period2 away_score_normaltime has_global_highlights  \
# 0                   2.0                   2.0                  True
# 1                   0.0                   1.0                  True
# 2                   0.0                   0.0                  True
# 3                   1.0                   1.0                  True
# 4                   1.0                   2.0                  True
# ..                  ...                   ...                   ...
# 834                 0.0                   1.0                 False
# 835                 1.0                   2.0                 False
# 836                 0.0                   2.0                 False
# 837                 0.0                   1.0                 False
# 838                 1.0                   1.0                 False
#
#      has_event_player_statistics has_event_player_heat_map  \
# 0                           True                      True
# 1                           True                      True
# 2                           True                      True
# 3                           True                      True
# 4                           True                      True
# ..                           ...                       ...
# 834                            0                         0
# 835                            0                         0
# 836                            0                         0
# 837                            0                         0
# 838                            0                         0
#
#         start_timestamp                           event_slug  round_info_name  \
# 0   2024-10-06 12:00:00                        aik-bk-hacken                0
# 1   2024-10-06 12:00:00             kalmar-ff-djurgardens-if                0
# 2   2024-10-05 13:00:00             halmstads-bk-hammarby-if                0
# 3   2024-10-06 14:30:00                 malmo-ff-ifk-varnamo                0
# 4   2024-10-06 14:30:00          ifk-norrkoping-ifk-goteborg                0
# ..                  ...                                  ...              ...
# 834 2024-10-05 18:00:00  coban-imperial-deportivo-malacateco                0
# 835 2024-10-09 13:15:00               ireland-u19-greece-u19                0
# 836 2024-10-09 08:00:00               romania-u19-norway-u19                0
# 837 2024-10-09 12:00:00                spain-u19-germany-u19                0
# 838 2024-10-09 13:00:00               france-u19-denmark-u19                0
#
#     round_info_slug
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 834               0
# 835               0
# 836               0
# 837               0
# 838               0
#
# [839 rows x 34 columns]

# %%
matchdata.columns
# Out:
# Index(['match_id', 'tournament_name', 'tournament_category_name',
#        'tournament_category_id', 'tournament_category_country_code',
#        'unique_tournament_id', 'tournament_is_group', 'tournament_id',
#        'season_name', 'season_year', 'season_id', 'round_info', 'custom_id',
#        'home_team_name', 'home_team_user_count', 'home_team_manager_name',
#        'home_team_id', 'away_team_name', 'away_team_user_count',
#        'away_team_manager_name', 'away_team_id', 'home_score_period1',
#        'home_score_period2', 'home_score_normaltime', 'away_score_period1',
#        'away_score_period2', 'away_score_normaltime', 'has_global_highlights',
#        'has_event_player_statistics', 'has_event_player_heat_map',
#        'start_timestamp', 'event_slug', 'round_info_name', 'round_info_slug'],
#       dtype='object')

# %%
from analysis.models import MatchInfo  # MatchInfo modelini içeri aktarıyoruz

class DataHandler:

    def __init__(self,matchdata):
        self.matchdata = matchdata
    
    def add_to_database(self):
        
    
        MatchInfo.objects.filter(match_id__in=self.matchdata['match_id'].tolist()).delete()
        
        print(matchdata)     
        match_data = [
            MatchInfo(
                match_id=row['match_id'],  # match_id (primary key)
                tournament_name=row.get('tournament_name', None),
                tournament_category_name=row.get('tournament_category_name', None),
                tournament_category_id=row.get('tournament_category_id', None),
                tournament_category_country_code=row.get('tournament_category_country_code', None),
                unique_tournament_id=row.get('unique_tournament_id', None),
                tournament_is_group=row.get('tournament_is_group', None),
                tournament_id=row.get('tournament_id', None),
                season_name=row.get('season_name', None),
                season_year=row.get('season_year', None),
                season_id=row.get('season_id', None),
                round_info=row.get('round_info', None),
                custom_id=row.get('custom_id', None),
                home_team_name=row.get('home_team_name', None),
                home_team_user_count=row.get('home_team_user_count', None),
                home_team_manager_name=row.get('home_team_manager_name', None),
                home_team_id=row.get('home_team_id', None),
                away_team_name=row.get('away_team_name', None),
                away_team_user_count=row.get('away_team_user_count', None),
                away_team_manager_name=row.get('away_team_manager_name', None),
                away_team_id=row.get('away_team_id', None),
                home_score_period1=row.get('home_score_period1', None),
                home_score_period2=row.get('home_score_period2', None),
                home_score_normaltime=row.get('home_score_normaltime', None),
                away_score_period1=row.get('away_score_period1', None),
                away_score_period2=row.get('away_score_period2', None),
                away_score_normaltime=row.get('away_score_normaltime', None),
                has_global_highlights=row.get('has_global_highlights', None),
                has_event_player_statistics=row.get('has_event_player_statistics', None),
                has_event_player_heat_map=row.get('has_event_player_heat_map', None),
                start_timestamp=row.get('start_timestamp', None),
                event_slug=row.get('event_slug', None),
                round_info_name=row.get('round_info_name', None),
                round_info_slug=row.get('round_info_slug', None),
            )
            for _, row in self.matchdata.iterrows()
        ]
        
        # 3. Verileri toplu olarak veritabanına ekleme
        MatchInfo.objects.bulk_create(match_data)
        print("Mevcut veriler silindi ve yeni veriler eklendi.")


api_send = DataHandler(matchdata)
api_send.add_to_database()
# Out:
#      match_id      tournament_name tournament_category_name  \
# 0    11907427          Allsvenskan                   Sweden
# 1    11907428          Allsvenskan                   Sweden
# 2    11907429          Allsvenskan                   Sweden
# 3    11907430          Allsvenskan                   Sweden
# 4    11907432          Allsvenskan                   Sweden
# ..        ...                  ...                      ...
# 834  12947741  Club Friendly Games                    World
# 835  12959814   U19 Friendly Games                    World
# 836  12962059   U19 Friendly Games                    World
# 837  12962060   U19 Friendly Games                    World
# 838  12962061   U19 Friendly Games                    World
#
#      tournament_category_id tournament_category_country_code  \
# 0                         9                              SWE
# 1                         9                              SWE
# 2                         9                              SWE
# 3                         9                              SWE
# 4                         9                              SWE
# ..                      ...                              ...
# 834                    1468                                0
# 835                    1468                                0
# 836                    1468                                0
# 837                    1468                                0
# 838                    1468                                0
#
#      unique_tournament_id  tournament_is_group  tournament_id  \
# 0                      40                False             24
# 1                      40                False             24
# 2                      40                False             24
# 3                      40                False             24
# 4                      40                False             24
# ..                    ...                  ...            ...
# 834                   853                False             86
# 835                   856                False           5799
# 836                   856                False           5799
# 837                   856                False           5799
# 838                   856                False           5799
#
#                   season_name season_year  ...  away_score_period1  \
# 0            Allsvenskan 2024        2024  ...                   0
# 1            Allsvenskan 2024        2024  ...                   1
# 2            Allsvenskan 2024        2024  ...                   0
# 3            Allsvenskan 2024        2024  ...                   0
# 4            Allsvenskan 2024        2024  ...                   1
# ..                        ...         ...  ...                 ...
# 834  Club Friendly Games 2024        2024  ...                   1
# 835   U19 Friendly Games 2024        2024  ...                   1
# 836   U19 Friendly Games 2024        2024  ...                   2
# 837   U19 Friendly Games 2024        2024  ...                   1
# 838   U19 Friendly Games 2024        2024  ...                   0
#
#      away_score_period2 away_score_normaltime has_global_highlights  \
# 0                   2.0                   2.0                  True
# 1                   0.0                   1.0                  True
# 2                   0.0                   0.0                  True
# 3                   1.0                   1.0                  True
# 4                   1.0                   2.0                  True
# ..                  ...                   ...                   ...
# 834                 0.0                   1.0                 False
# 835                 1.0                   2.0                 False
# 836                 0.0                   2.0                 False
# 837                 0.0                   1.0                 False
# 838                 1.0                   1.0                 False
#
#      has_event_player_statistics has_event_player_heat_map  \
# 0                           True                      True
# 1                           True                      True
# 2                           True                      True
# 3                           True                      True
# 4                           True                      True
# ..                           ...                       ...
# 834                            0                         0
# 835                            0                         0
# 836                            0                         0
# 837                            0                         0
# 838                            0                         0
#
#         start_timestamp                           event_slug  round_info_name  \
# 0   2024-10-06 12:00:00                        aik-bk-hacken                0
# 1   2024-10-06 12:00:00             kalmar-ff-djurgardens-if                0
# 2   2024-10-05 13:00:00             halmstads-bk-hammarby-if                0
# 3   2024-10-06 14:30:00                 malmo-ff-ifk-varnamo                0
# 4   2024-10-06 14:30:00          ifk-norrkoping-ifk-goteborg                0
# ..                  ...                                  ...              ...
# 834 2024-10-05 18:00:00  coban-imperial-deportivo-malacateco                0
# 835 2024-10-09 13:15:00               ireland-u19-greece-u19                0
# 836 2024-10-09 08:00:00               romania-u19-norway-u19                0
# 837 2024-10-09 12:00:00                spain-u19-germany-u19                0
# 838 2024-10-09 13:00:00               france-u19-denmark-u19                0
#
#     round_info_slug
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 834               0
# 835               0
# 836               0
# 837               0
# 838               0
#
# [839 rows x 34 columns]
# Mevcut veriler silindi ve yeni veriler eklendi.
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 12:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 13:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 14:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 15:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 18:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 12:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 15:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 15:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 11:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 16:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 23:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 20:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 18:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 00:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 00:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 19:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 22:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 18:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 21:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 21:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 23:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 18:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 12:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 20:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 19:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 18:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 20:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 00:05:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 18:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 20:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 18:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 21:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 23:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 06:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 14:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 14:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 11:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 16:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 16:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 17:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 13:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 20:25:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 00:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 01:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 02:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 23:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 07:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 05:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 20:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 21:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 17:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 23:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 15:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 20:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 00:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 02:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 19:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 08:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 01:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 22:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 19:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 07:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 23:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 17:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 15:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 12:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 12:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 18:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 16:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 16:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 02:05:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 03:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 01:05:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 16:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 17:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 18:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 14:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 14:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 19:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 14:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 12:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 13:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 12:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 15:25:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 16:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 14:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 10:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 17:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 10:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 17:35:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 18:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 08:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 17:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 10:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 13:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 18:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 18:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 18:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 12:05:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 10:05:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 23:20:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 00:20:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 21:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 22:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 01:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 21:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 20:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 18:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 08:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 13:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 12:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 16:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 09:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 08:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 15:25:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 15:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 17:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 13:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 15:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:10:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 15:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 08:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 09:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 10:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 13:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 12:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 09:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 13:50:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 21:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 10:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 11:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 16:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 12:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 10:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 16:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 16:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 19:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-05 21:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-06 21:30:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 18:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 15:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 16:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 19:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 16:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-08 19:00:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-07 20:15:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 18:45:00) while time zone support is active.
#   warnings.warn(
# /home/ahmety/Masaüstü/myenv/lib/python3.12/site-packages/django/db/models/fields/__init__.py:1665: RuntimeWarning: DateTimeField MatchInfo.start_timestamp received a naive datetime (2024-10-09 13:15:00) while time zone support is active.
#   warnings.warn(
